# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernsrea/reimagined-eureka/blob/main/Discreteflow_Cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facebookresearch/flow_matching.git
# %cd flow_matching/examples/image
# Out:
# Cloning into 'flow_matching'...
# remote: Enumerating objects: 1418, done.
# remote: Counting objects: 100% (798/798), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 1418 (delta 760), reused 640 (delta 640), pack-reused 620 (from 1)
# Receiving objects: 100% (1418/1418), 6.72 MiB | 11.38 MiB/s, done.
# Resolving deltas: 100% (1113/1113), done.
# /content/flow_matching/examples/image/flow_matching/examples/image

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 59.1 MB/s eta 0:00:00
# ...

# %%
# !pip install torchdiffeq

# %%
# !pip install flow_matching
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !python submitit_train_new.py \
    --dataset=cifar10 \
    --discrete_flow_matching \
    --batch_size=32 \
    --accum_iter=1 \
    --cfg_scale=0.0 \
    --use_ema \
    --epochs=3000 \
    --class_drop_prob=1.0 \
    --compute_fid \
    --sym_func \
    --num_workers=2
# Out:
# 2025-04-21 19:22:29 INFO     Process group: 1 tasks, rank: 0
# Not using distributed mode
# 2025-04-21 19:22:29 INFO     job dir: /content/flow_matching/examples/image
# 2025-04-21 19:22:29 INFO     Namespace(batch_size=32,
# epochs=3000,
# accum_iter=1,
# lr=0.0001,
# optimizer_betas=[0.9,
# 0.95],
# decay_lr=False,
# class_drop_prob=1.0,
# skewed_timesteps=False,
# edm_schedule=False,
# use_ema=True,
# dataset='cifar10',
# data_path='./data/image_generation',
# output_dir='/content/shared_dir/colab_user/experiments/colab_run_20250421_192229',
# ode_method='midpoint',
# ode_options={'step_size': 0.01},
# sym=0.0,
# temp=1.0,
# sym_func=True,
# sampling_dtype='float32',
# cfg_scale=0.0,
# fid_samples=50000,
# device='cuda',
# seed=0,
# resume='',
# start_epoch=0,
# eval_only=False,
# eval_frequency=50,
# compute_fid=True,
# save_fid_samples=False,
# num_workers=2,
# pin_mem=True,
# world_size=1,
# local_rank=-1,
# dist_on_itp=False,
# dist_url='env://',
# test_run=False,
# ...
